# %% [markdown]
# # Neural Networks

# %% [markdown]
# ## Laden des MNIST-Datensatzes

# %%
from mnist import MnistDataset

mnist_test  = MnistDataset('mnist_test.csv')
mnist_train = MnistDataset('mnist_train.csv')

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5,5))
mnist_test.plot_list(1,10)

plt.show()

# %%
#print(mnist_train.values()[0:2])

# %%
X_train, y_train = mnist_train.values()[:][1:], mnist_train.values()[:][0]
#print(y_train)

# %% [markdown]
# ## Erzeugung und Training des Klassifizieres (Neuronales Netzwerk)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier( max_iter=1, random_state=1)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.neural_network import MLPClassifier
#       2 clf = MLPClassifier( max_iter=1, random_state=1)
# ----> 3 clf.fit(X_train, y_train)
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:753, in BaseMultilayerPerceptron.fit(self, X, y)
#     735 @_fit_context(prefer_skip_nested_validation=True)
#     736 def fit(self, X, y):
#     737     """Fit the model to data matrix X and target(s) y.
#     738
#     739     Parameters
#    (...)
#     751         Returns a trained MLP model.
#     752     """
# --> 753     return self._fit(X, y, incremental=False)
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:442, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     435     raise ValueError(
#     436         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     437     )
#     438 first_pass = not hasattr(self, "coefs_") or (
#     439     not self.warm_start and not incremental
#     440 )
# --> 442 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     444 n_samples, n_features = X.shape
#     446 # Ensure y is 2D
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1093, in MLPClassifier._validate_input(self, X, y, incremental, reset)
#    1092 def _validate_input(self, X, y, incremental, reset):
# -> 1093     X, y = self._validate_data(
#    1094         X,
#    1095         y,
#    1096         accept_sparse=["csr", "csc"],
#    1097         multi_output=True,
#    1098         dtype=(np.float64, np.float32),
#    1099         reset=reset,
#    1100     )
#    1101     if y.ndim == 2 and y.shape[1] == 1:
#    1102         y = column_or_1d(y, warn=True)
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\utils\validation.py:1165, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    (...)
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1165 check_consistent_length(X, y)
#    1167 return X, y
#
# File ~\AppData\Local\anaconda3\envs\ki\Lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [59999, 785]

# %%
clf.predict_proba(X_test[:1])

# %%
clf.predict(X_test[:5, :])

clf.score(X_test, y_test)
