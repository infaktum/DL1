# %% [raw]
# # SK01 - Multi-Layered Perceptron
#
# Eines der schlagkräftigsten
# `sklearn` enthält auch eine Impementierung des Perzeptrons. Wir verwenden sie, um handgeschriebene Ziffern zu erkennen, und benutzen dazu den Digits-Datensatz aus `sklearn`.

# %% [markdown]
# ## Digits-Daten

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def gallery(images, rows, cols, cmap=None):
    for n in range(rows * cols):          
        plt.subplot(rows, cols,n+1)
        ax = plt.gca()
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)          
        plt.imshow(images[n], cmap)

# %%
from sklearn.datasets import load_digits

digits = load_digits()
X, y, images = digits.data, digits.target, digits.images
gallery(images,5,8,cmap='Blues')

# %% [markdown]
# ## Training des Perzeptrons

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier( max_iter=1000)

mlpc.fit(X_train, y_train)
# Out:
# Perceptron()

# %% [markdown]
# ## Test des Ergebnisses

# %%
res = perceptron.predict(X[:10])
print(res)
# Out:
# [0 1 2 3 4 1 6 7 8 9]

# %%
print(f'Anzahl der Digits:\t {len(X)}')
print(f'Korrekt erkannt:\t { (perceptron.predict(X) == y).sum()}')
# Out:
# Anzahl der Digits:	 1797
# Korrekt erkannt:	 1688

# %%
images_fehler= images[perceptron.predict(X) != y]
gallery(images_fehler,5,8,cmap='Reds')
